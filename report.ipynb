# %%
from PIL import Image
import numpy as np

from src.convolution import convolution_test
from src.im2col import im2col_conv_test

# %%
img = Image.open('./data/monarch-butterfly-450x450.jpg')
img_array = np.array(img)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x450>

# %%
convolution_test(img_array, padding = 1, stride = 1)
# Out:
# Passed convolution test:
# 	Params: n_filter = 1, kernel_size = (1, 1)
# Passed convolution test:
# 	Params: n_filter = 1, kernel_size = (3, 3)
# Passed convolution test:
# 	Params: n_filter = 1, kernel_size = (5, 5)
# Passed convolution test:
# 	Params: n_filter = 1, kernel_size = (7, 7)
# Passed convolution test:
# 	Params: n_filter = 2, kernel_size = (1, 1)
# Passed convolution test:
# 	Params: n_filter = 2, kernel_size = (3, 3)
# Passed convolution test:
# 	Params: n_filter = 2, kernel_size = (5, 5)
# Passed convolution test:
# 	Params: n_filter = 2, kernel_size = (7, 7)
# Passed convolution test:
# 	Params: n_filter = 3, kernel_size = (1, 1)
# Passed convolution test:
# 	Params: n_filter = 3, kernel_size = (3, 3)
# Passed convolution test:
# 	Params: n_filter = 3, kernel_size = (5, 5)
# Passed convolution test:
# 	Params: n_filter = 3, kernel_size = (7, 7)

# %%
im2col_conv_test(img_array, padding = 1, stride = 1)
# Out:
# Passed im2col convolution test:
# 	Parameters: n_filter = 1, kernel_size = (1, 1)
# Passed im2col convolution test:
# 	Parameters: n_filter = 1, kernel_size = (3, 3)
# Passed im2col convolution test:
# 	Parameters: n_filter = 1, kernel_size = (5, 5)
# Passed im2col convolution test:
# 	Parameters: n_filter = 1, kernel_size = (7, 7)
# Passed im2col convolution test:
# 	Parameters: n_filter = 2, kernel_size = (1, 1)
# Passed im2col convolution test:
# 	Parameters: n_filter = 2, kernel_size = (3, 3)
# Passed im2col convolution test:
# 	Parameters: n_filter = 2, kernel_size = (5, 5)
# Passed im2col convolution test:
# 	Parameters: n_filter = 2, kernel_size = (7, 7)
# Passed im2col convolution test:
# 	Parameters: n_filter = 3, kernel_size = (1, 1)
# Passed im2col convolution test:
# 	Parameters: n_filter = 3, kernel_size = (3, 3)
# Passed im2col convolution test:
# 	Parameters: n_filter = 3, kernel_size = (5, 5)
# Passed im2col convolution test:
# ...
